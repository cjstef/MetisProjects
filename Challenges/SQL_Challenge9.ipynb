# %% [markdown]
# Part I:
#
# 1. Which customers are from the UK?
# SELECT * FROM [Customers] WHERE Country = 'UK';
#
# 2. What is the name of the customer who has the most orders?
# SELECT CustomerID, COUNT() FROM [Orders] GROUP BY CustomerID
# ORDER BY COUNT() DESC;
#
# 3. Which supplier has the highest average product price?
# SELECT Price, SupplierID FROM [Products] GROUP BY SupplierID
# ORDER BY Price DESC;
#
# 4. How many different countries are all the customers from? (*Hint:* consider [DISTINCT](http://www.w3schools.com/sql/sql_distinct.asp).)
# SELECT DISTINCT Country FROM [Customers];
#
# 5. What category appears in the most orders?
# Dairy Products
#
# 6. What was the total cost for each order?
# ORder id 10372
#
# 7. Which employee made the most sales (by total price)?
# Margaret Peacock
#
# 8. Which employees have BS degrees? (*Hint:* look at the [LIKE](http://www.w3schools.com/sql/sql_like.asp) operator.)
# Janet Leveriling
#
# 9. Which supplier of three or more products has the highest average product price? (*Hint:* look at the [HAVING](http://www.w3schools.com/sql/sql_having.asp) operator.)
# Tokyo Traders

# %%
import sqlite3

# %%
conn = sqlite3.connect('database.sqlite')
c = conn.cursor()

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(c.fetchall())
# Out:
# [(u'sqlite_sequence',), (u'Player_Attributes',), (u'Player',), (u'Match',), (u'League',), (u'Country',), (u'Team',), (u'Team_Attributes',)]

# %%
import pandas as pd

pd.read_sql_query('SELECT home_team_goal, home_team_api_id FROM Match GROUP BY home_team_api_id ORDER BY home_team_goal DESC',conn)
# Out:
#      home_team_goal  home_team_api_id
# 0                 6             10261
# 1                 5              8277
# 2                 5              8302
# 3                 5              8342
# 4                 5              8456
# 5                 5              9823
# 6                 4              8021
# 7                 4              8305
# 8                 4              8464
# 9                 4              8548
# 10                4              8583
# 11                4              8721
# 12                4              9882
# 13                4              9991
# 14                4             10000
# 15                4             10192
# 16                4             10264
# 17                4             10265
# 18                3              4087
# 19                3              6421
# 20                3              6433
# 21                3              6601
# 22                3              7794
# 23                3              8023
# ...

# %%
pd.read_sql_query('SELECT away_team_goal, away_team_api_id  from Match GROUP BY away_team_api_id ORDER BY away_team_goal DESc',conn)
# Out:
#      away_team_goal  away_team_api_id
# 0                 6             10265
# 1                 5              2183
# 2                 5              8277
# 3                 5              9788
# 4                 5             10235
# 5                 4              8529
# 6                 4              8548
# 7                 4              8560
# 8                 4              8673
# 9                 4              9772
# 10                4              9773
# 11                4              9831
# 12                4              9847
# 13                3              6433
# 14                3              7878
# 15                3              8357
# 16                3              8466
# 17                3              8559
# 18                3              8633
# 19                3              8649
# 20                3              8654
# 21                3              8668
# 22                3              8722
# 23                3              9768
# ...
